# %%
import numpy as np
import altair as alt
import pandas as pd
from html.parser import HTMLParser
import os
import yaml
from bs4 import BeautifulSoup
from bs4.element import NavigableString

import geopandas as gpd
import pickle
import re

# %% [markdown]
# ```
# html_file = "./state-territorial-universities.html"
# os.path.isfile(html_file)
# ```

# %% [markdown]
# ```
# def make_list(tag):
#     elements = []
#     if tag.name=='ul':
#         for st in tag.children:
#             if st.name == 'li' and st.a:
#                 all_ul = [] if st is NavigableString else st.find_all('ul')
#                 if len(all_ul)==0:
#                     elements.append(str(st.a.contents[0]))
#                 elif st.a:
#                     elements.append({str(st.a.contents[0]): make_list(all_ul[0])})
#     return elements
# ```

# %% [markdown]
# ```
# elements = {}
# with open(html_file) as file:
#     curr_state = ''
#     soup = BeautifulSoup(file, "html.parser").contents[-1]
#     for tag in soup.body.contents:
#         if tag.name=='h2' and tag.contents[0].name=='span':
#             curr_state = str(tag.contents[0].contents[0])
#         elif tag.name=='ul':
#             elements[curr_state] = make_list(tag)
# elements
# with open('universities.yaml', 'w') as out_file:
#     yaml.dump(elements, out_file)
# ```

# %%
cc_data = pd.read_csv('data_processed.csv')

if False:
    cc_data['lon'] = cc_data['geometry'].map(lambda p: float(re.findall(r'-?\d+[:.]\d+\w', str(p))[0]))
    cc_data['lat'] = cc_data['geometry'].map(lambda p: float(re.findall(r'-?\d+[:.]\d+\w', str(p))[1]))
cc_data
# Out:
#      unitid                                   name           city state  \
# 0    999911                         Air University     Montgomery    AL
# 1    100654               Alabama A & M University         Normal    AL
# 2    100724               Alabama State University     Montgomery    AL
# 3    100858                      Auburn University         Auburn    AL
# 4    100830        Auburn University at Montgomery     Montgomery    AL
# ..      ...                                    ...            ...   ...
# 465  240480  University of Wisconsin-Stevens Point  Stevens Point    WI
# 466  240417          University of Wisconsin-Stout      Menomonie    WI
# 467  240426       University of Wisconsin-Superior       Superior    WI
# 468  240189     University of Wisconsin-Whitewater     Whitewater    WI
# 469  240727                  University of Wyoming        Laramie    WY
#
#                                  Undergraduate Program  \
# 0                    Baccalaureate/Associates Colleges
# 1    Professions plus arts & sciences some graduate...
# 2    Balanced arts & sciences/professions some grad...
# 3    Professions plus arts & sciences high graduate...
# 4    Professions plus arts & sciences some graduate...
# ..                                                 ...
# 465  Balanced arts & sciences/professions some grad...
# 466        Professions focus some graduate coexistence
# 467  Balanced arts & sciences/professions some grad...
# 468  Professions plus arts & sciences some graduate...
# 469  Professions plus arts & sciences high graduate...
#
#                                       Graduate Program  \
# 0               Research Doctoral Single program Other
# 1              Research Doctoral Professional-dominant
# 2              Research Doctoral Professional-dominant
# 3    Research Doctoral Comprehensive programs with ...
# 4             Postbaccalaureate Comprehensive programs
# ..                                                 ...
# 465  Postbaccalaureate Other-dominant with Arts & S...
# 466  Postbaccalaureate Education-dominant with Arts...
# 467  Postbaccalaureate Education-dominant with Arts...
# 468           Postbaccalaureate Comprehensive programs
# 469                    Research Doctoral STEM-dominant
#
#           Enrollment Profile  \
# 0    Very high undergraduate
# 1         High undergraduate
# 2    Very high undergraduate
# 3         High undergraduate
# 4         High undergraduate
# ..                       ...
# 465  Very high undergraduate
# 466  Very high undergraduate
# 467  Very high undergraduate
# 468  Very high undergraduate
# 469       High undergraduate
#
#                                  Undergraduate Profile  \
# 0                            Two-year higher part-time
# 1      Four-year full-time inclusive lower transfer-in
# 2      Four-year full-time inclusive lower transfer-in
# 3    Four-year full-time more selective lower trans...
# 4    Four-year medium full-time lower transfer-in h...
# ..                                                 ...
# 465    Four-year full-time inclusive lower transfer-in
# 466    Four-year full-time selective lower transfer-in
# 467  Four-year medium full-time lower transfer-in h...
# 468    Four-year full-time inclusive lower transfer-in
# 469   Four-year full-time selective higher transfer-in
#
#                                Size & Setting  \
# 0    Four-year large primarily nonresidential
# 1         Four-year medium highly residential
# 2         Four-year medium highly residential
# 3    Four-year large primarily nonresidential
# 4      Four-year medium primarily residential
# ..                                        ...
# 465    Four-year medium primarily residential
# 466    Four-year medium primarily residential
# 467     Four-year small primarily residential
# 468     Four-year large primarily residential
# 469     Four-year large primarily residential
#
#                                                  Basic full_state  \
# 0     Master's Colleges & Universities Larger Programs    Alabama
# 1     Master's Colleges & Universities Larger Programs    Alabama
# 2    Doctoral Universities Doctoral/Professional Un...    Alabama
# 3    Doctoral Universities Very High Research Activity    Alabama
# 4     Master's Colleges & Universities Larger Programs    Alabama
# ..                                                 ...        ...
# 465   Master's Colleges & Universities Medium Programs  Wisconsin
# 466   Master's Colleges & Universities Larger Programs  Wisconsin
# 467   Master's Colleges & Universities Medium Programs  Wisconsin
# 468   Master's Colleges & Universities Larger Programs  Wisconsin
# 469       Doctoral Universities High Research Activity    Wyoming
#
#                                                address         lon        lat
# 0    Air University, Sycamore Street, 36112, Sycamo...  -86.345485  32.385264
# 1    Air University, Sycamore Street, 36112, Sycamo...  -86.345485  32.385264
# 2    University of Alabama, Thomas Street, 35401, T...  -87.539673  33.212082
# 3    Auburn University, 36849, Auburn, AL, United S...  -85.495949  32.591988
# 4    University Church of Christ, Atlanta Highway, ...  -86.219345  32.382527
# ..                                                 ...         ...        ...
# 465  University of Wisconsin–Stevens Point, Reserve...  -89.569467  44.531640
# 466  University of Wisconsin-Stout, 712, Broadway S...  -91.926516  44.871548
# 467  University District, 54880, Superior, Wisconsi...  -92.092294  46.720951
# 468  University of Wisconsin-Madison, Marion Street...  -89.430959  43.080274
# 469  University of Wyoming Experimental Station, Ar... -104.654132  41.151648
#
# [470 rows x 14 columns]

# %%
from geopandas.tools import geocode

if False:
    cc_data = pd.read_csv('~/Downloads/cc_download.csv')

    geos = geocode(cc_data['name'], provider='photon', user_agent='unc-comp-790')
    cc_data = cc_data.join(geos)
    cc_data.head()

# %%
not_found = cc_data.loc[cc_data.geometry.apply(lambda p: p.is_empty)]
not_found.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 not_found = cc_data.loc[cc_data.geometry.apply(lambda p: p.is_empty)]
#       2 not_found.head()
#
# File ~\Anaconda3\envs\infovis\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'geometry'

# %%
# cc_data.to_csv('data_processed.csv')

# %%
from geopandas.tools import geocode

geos = geocode(not_found['name'], provider='photon', user_agent='unc-comp-790')
geos
# Out:
#                         geometry  \
# 18                   POINT EMPTY
# 178     POINT (0.00970 51.54433)
# 219    POINT (77.23261 28.66446)
# 220   POINT (-90.34263 33.51126)
# 236    POINT (72.59375 23.10587)
# 248  POINT (151.23466 -33.90624)
# 261   POINT (-74.17903 40.74213)
# 270                  POINT EMPTY
# 276   POINT (-73.89016 40.87334)
# 278   POINT (-73.82520 40.73700)
# 294    POINT (-0.00512 51.48077)
# 296  POINT (-122.02395 37.40813)
# 362   POINT (-74.24522 40.74414)
# 373  POINT (-111.65500 35.18344)
# 374   POINT (-91.77386 37.95289)
# 381   POINT (-85.73034 36.03634)
# 427   POINT (-73.19415 44.47374)
# 439   POINT (-77.95838 37.09116)
#
#                                                address
# 18                                                None
# 178  University of East London (Stratford Campus), ...
# 219  Indira Gandhi Delhi Technical University for W...
# 220  Mississippi Valley State University, County Ro...
# 236  Gujarat Technological University, 382424, Ahme...
# 248  University of New South Wales Randwick Campus,...
# 261  New Jersey Institute of Technology, University...
# 270                                               None
# 276  Bedford Park Boulevard–Lehman College, Bedford...
# 278  Main Street & CUNY Queens College, Main Street...
# 294  National Maritime Museum, Old Royal Naval Coll...
# 296  Cogswell Polytechnical College, Bordeaux Drive...
# 362  Caroline D. Schwartz College of Nursing, South...
# 373  Northern Arizona University, West Forest Meado...
# 374  Missouri University of Science and Technology,...
# 381  Tennessee Technological University Appalachian...
# 427  University of Vermont, Davis Road, 05401, Davi...
# 439  Virginia Polytechnical Institute Land, Virgini...

# %%
# cc_data['geometry'][not_found.index] = not_found['geometry']

# %%
cc_data['lon'] = cc_data['geometry'].map(lambda p: None if p.is_empty else p.x)
cc_data['lat'] = cc_data['geometry'].map(lambda p: None if p.is_empty else p.y)
cc_data[['lon','lat']].head()
# Out:
#          lon        lat
# 0 -86.345485  32.385264
# 1 -86.568423  34.783895
# 2 -86.345485  32.385264
# 3 -85.495949  32.591988
# 4 -86.345485  32.385264

# %%
wrong_state = cc_data.loc[~cc_data.apply(lambda r: r['city'] in r['address'] or r['name'] in r['address'], axis=1)]
wrong_state[['name','city','address']]
# Out:
#                                                   name               city  \
# 63             Colorado State University-Global Campus             Aurora
# 67   University of Colorado Denver/Anschutz Medical...             Denver
# 83                      The University of West Florida          Pensacola
# 160         Northwestern State University of Louisiana       Natchitoches
# 187              University of Massachusetts-Dartmouth    North Dartmouth
# 199                    Saginaw Valley State University  University Center
# 212                University of Minnesota-Twin Cities        Minneapolis
# 318                        Ohio University-Main Campus             Athens
# 323                Wright State University-Main Campus             Dayton
# 354                  The Pennsylvania State University    University Park
# 357                 University of Puerto Rico-Mayaguez           Mayaguez
# 439                          Virginia State University         Petersburg
#
#                                                address
# 63   Colorado State University - Mountain Campus, S...
# 67   University of Colorado Anschutz Medical Campus...
# 83   Hillel at the University of Florida, West Univ...
# 160  Northwestern State University of Leesville, Un...
# 187  University of Massachusetts Dartmouth, 285, Ol...
# 199  Mississippi Valley State University, Mississip...
# 212  League of Minnesota Cities Building, Universit...
# 318  University of Cincinnati Main Campus, Victory ...
# 323  Wright State University, 3640, Colonel Glenn H...
# 354  Hospital of the University of Pennsylvania, 34...
# 357  Universidad de Puerto Rico - Recinto Universit...
# 439  University of Virginia, Earhart Street, 22901,...

# %%
import requests
import time

url = "https://us1.locationiq.com/v1/search"

responses = []

for i in wrong_state.index:
    data = {
        'key': 'pk.4390cfb99f9a354407e60d9cb64cd356',
        'street': wrong_state['name'][i],
        'format': 'json',
        'city': wrong_state['city'][i]
    }
    response = requests.get(url, params=data)
    responses.append(response.json())
    time.sleep(0.5)
responses
# Out:
# [{'error': 'Unable to geocode'},
#  {'error': 'Unable to geocode'},
#  {'error': 'Unable to geocode'},
#  [{'place_id': '210638515',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '463534916',
#    'boundingbox': ['41.9308182', '41.943627', '-88.7970677', '-88.7498739'],
#    'lat': '41.937093399999995',
#    'lon': '-88.78267841443035',
#    'display_name': 'Northern Illinois University, 1425, West Lincoln Highway, DeKalb, DeKalb Township, DeKalb County, Illinois, 60115, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8906416873565544,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  {'error': 'Unable to geocode'},
#  {'error': 'Unable to geocode'},
#  {'error': 'Unable to geocode'},
#  [{'place_id': '332405759081',
#    'osm_type': 'node',
#    'osm_id': '358269095',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '41.62959',
#    'lon': '-71.006186',
#    'display_name': 'University of Massachusetts Dartmouth, 285, Old Westport Road, Dartmouth, Bristol County, Massachusetts, 02747, USA',
#    'boundingbox': ['41.62959', '41.62959', '-71.006186', '-71.006186'],
#    'importance': 0.25}],
#  [{'place_id': '305375187',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'relation',
#    'osm_id': '13708038',
#    'boundingbox': ['42.6694955', '42.7353807', '-84.5093894', '-84.4618929'],
#    'lat': '42.7024238',
#    'lon': '-84.48032837503001',
#    'display_name': 'Michigan State University, 426, Auditorium Road, East Lansing, Ingham County, Michigan, 48910, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 1.079602686432449,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '230872243',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '597008535',
#    'boundingbox': ['47.0978732', '47.1217689', '-88.5646632', '-88.5334142'],
#    'lat': '47.1099114',
#    'lon': '-88.55115132910507',
#    'display_name': 'Michigan Technological University, 1400, Townsend Drive, Houghton, Portage Township, Houghton County, Michigan, 49931, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8487485870051532,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '330337916082',
#    'osm_type': 'way',
#    'osm_id': '361928264',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '33.511739',
#    'lon': '-90.342305',
#    'display_name': 'Mississippi Valley State University, Mississippi Valley State University, Leflore County, Mississippi, 38941, USA',
#    'boundingbox': ['33.5057272', '33.5191909', '-90.352338', '-90.3335654'],
#    'importance': 0.25},
#   {'place_id': '332109451239',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '33.516811',
#    'lon': '-90.343452',
#    'display_name': 'Mississippi Valley State University, Leflore County, Mississippi, USA',
#    'boundingbox': ['33.503558', '33.53211', '-90.356987', '-90.327274'],
#    'importance': 0.25}],
#  [{'place_id': '127253947',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '91011061',
#    'boundingbox': ['42.2742685', '42.292417', '-85.6239759', '-85.5967333'],
#    'lat': '42.28333755',
#    'lon': '-85.60950673080742',
#    'display_name': 'Western Michigan University, 1903, West Michigan Avenue, Kalamazoo, Kalamazoo County, Michigan, 49008, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8965374421755099,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '161095685',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '219434550',
#    'boundingbox': ['44.4516273', '44.4628978', '-95.7659748', '-95.7563582'],
#    'lat': '44.45744485',
#    'lon': '-95.75923679578392',
#    'display_name': 'Southwest Minnesota State University, 1501, State Street, Marshall, Lyon County, Minnesota, 56258, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8617625908494562,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '133847820',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '116426265',
#    'boundingbox': ['46.815027', '46.8257379', '-92.0922113', '-92.0768832'],
#    'lat': '46.8203898',
#    'lon': '-92.08527412081386',
#    'display_name': 'University of Minnesota Duluth, 1049, University Drive, Duluth, Saint Louis County, Minnesota, 55812, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.9384205148504461,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  {'error': 'Unable to geocode'},
#  [{'place_id': '277121665',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '895007900',
#    'boundingbox': ['33.403116', '33.4748329', '-88.8056582', '-88.7760774'],
#    'lat': '33.4386876',
#    'lon': '-88.79432320417112',
#    'display_name': 'Mississippi State University, 75, Herbert Street, College Vista, Mississippi State, Oktibbeha County, Mississippi, 39759, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 1.0057128807474127,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  {'error': 'Unable to geocode'},
#  [{'place_id': '304059731',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'relation',
#    'osm_id': '2601235',
#    'boundingbox': ['31.3248541', '31.3356485', '-89.3453895', '-89.3220527'],
#    'lat': '31.3286452',
#    'lon': '-89.3367311705755',
#    'display_name': 'University of Southern Mississippi, 118, College Drive, Hattiesburg, Forrest County, Mississippi, 39401, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.9594944045936054,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '332756312371',
#    'osm_type': 'relation',
#    'osm_id': '14160076',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '40.808295',
#    'lon': '-73.798623',
#    'display_name': 'SUNY Maritime College, 6, Pennyfield Avenue, Throgs Neck, New York, Bronx County, New York, 10465, USA',
#    'boundingbox': ['40.8050542', '40.8101005', '-73.8018944', '-73.7938929'],
#    'importance': 0.25},
#   {'place_id': '332660536208',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '40.809134',
#    'lon': '-73.801298',
#    'display_name': 'SUNY Maritime Circle, Throgs Neck, New York, Bronx County, New York, 10465, USA',
#    'boundingbox': ['40.809001', '40.809199', '-73.801496', '-73.801287'],
#    'importance': 0.25},
#   {'place_id': '333858222575',
#    'osm_type': 'node',
#    'osm_id': '8450438594',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '40.809163',
#    'lon': '-73.801231',
#    'display_name': 'SUNY Maritime Circle & Shepard Avenue, Throgs Neck, New York, Bronx County, New York, 10465, USA',
#    'boundingbox': ['40.809163', '40.809163', '-73.801231', '-73.801231'],
#    'importance': 0.25}],
#  {'error': 'Unable to geocode'},
#  {'error': 'Unable to geocode'},
#  [{'place_id': '330221011779',
#    'osm_type': 'way',
#    'osm_id': '50033013',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '39.949702',
#    'lon': '-75.194404',
#    'display_name': 'Hospital of the University of Pennsylvania, 3400, Spruce Street, University City, Philadelphia, Philadelphia County, Pennsylvania, 19104, USA',
#    'boundingbox': ['39.9488498', '39.9507311', '-75.196034', '-75.192672'],
#    'importance': 0.25},
#   {'place_id': '333290659296',
#    'osm_type': 'relation',
#    'osm_id': '306632',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '40.006009',
#    'lon': '-83.01132',
#    'display_name': 'The Ohio State University, 281, West Lane Avenue, University Area, Columbus, Franklin County, Ohio, 43210, USA',
#    'boundingbox': ['40.0008701', '40.0063742', '-83.0207044', '-83.0083176'],
#    'importance': 0.25},
#   {'place_id': '333937805278',
#    'osm_type': 'way',
#    'osm_id': '375742949',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '39.99507',
#    'lon': '-83.018736',
#    'display_name': 'Wexner Medical Center at The Ohio State University, 410, West Tenth Avenue, University Area, Columbus, Franklin County, Ohio, 43210, USA',
#    'boundingbox': ['39.9921959', '39.9976288', '-83.022239', '-83.0146875'],
#    'importance': 0.25}],
#  [{'place_id': '161549948',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '221078988',
#    'boundingbox': ['18.2066798', '18.2214206', '-67.1493231', '-67.1352006'],
#    'lat': '18.2138235',
#    'lon': '-67.14256802417052',
#    'display_name': 'Universidad de Puerto Rico - Recinto Universitario de Mayagüez, Calle San Miguel, Dulces Labios, Barrio Pueblo, Mayagüez, Puerto Rico, 00682, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.5483764706069638,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '113916171',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '28337037',
#    'boundingbox': ['40.2740695', '40.2847017', '-111.7241929', '-111.704896'],
#    'lat': '40.27941055',
#    'lon': '-111.71788683218048',
#    'display_name': 'Utah Valley University, 800, West University Parkway, Orem, Utah County, Utah, 84058, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8061455465323606,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '66097253',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'node',
#    'osm_id': '6131742679',
#    'boundingbox': ['44.6400607', '44.6401607', '-72.6716829', '-72.6715829'],
#    'lat': '44.6401107',
#    'lon': '-72.6716329',
#    'display_name': 'Northern Vermont University-Johnson, 3737, College Hill, Johnson, Lamoille County, Vermont, 05656, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.4200999999999999,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '238690508',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '654367395',
#    'boundingbox': ['44.6372277', '44.6518911', '-72.6776081', '-72.6580248'],
#    'lat': '44.6445964',
#    'lon': '-72.66694580291698',
#    'display_name': 'Northern Vermont University-Johnson, 337, South Pond Road, Johnson, Lamoille County, Vermont, 05656, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.4200999999999999,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '188514431',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '337509448',
#    'boundingbox': ['38.8240883', '38.8385555', '-77.3301778', '-77.2972191'],
#    'lat': '38.83133325',
#    'lon': '-77.30798838879116',
#    'display_name': 'George Mason University, 4400, University Drive, George Mason, Fairfax County, Virginia, 22030, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.9047056761884475,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '302773841',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1092799917',
#    'boundingbox': ['38.8302783', '38.8303546', '-77.3256775', '-77.3255801'],
#    'lat': '38.83031645',
#    'lon': '-77.32562879967448',
#    'display_name': 'George Mason University, Braddock Road, George Mason, Fairfax County, Virginia, 22030, USA',
#    'class': 'building',
#    'type': 'school',
#    'importance': 0.40001}],
#  [{'place_id': '303879372',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'relation',
#    'osm_id': '1214378',
#    'boundingbox': ['37.2102892', '37.2347283', '-80.4400394', '-80.4118735'],
#    'lat': '37.22192675',
#    'lon': '-80.42728184013652',
#    'display_name': 'Virginia Polytechnic Institute and State University, 800, Drillfield Drive, Blacksburg, Montgomery County, Virginia, 24060, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 1.2443778495209437,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  {'error': 'Unable to geocode'},
#  [{'place_id': '305056713',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'relation',
#    'osm_id': '11594877',
#    'boundingbox': ['37.2585164', '37.2806219', '-76.7410352', '-76.7030427'],
#    'lat': '37.26908455',
#    'lon': '-76.72273688917291',
#    'display_name': 'College of William and Mary, Ironbound Road, Indigo Terrace, Williamsburg, James City County, Virginia, 23187, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8086875441813045,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '10759589',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'node',
#    'osm_id': '1176230358',
#    'boundingbox': ['37.2730656', '37.2731656', '-76.7090691', '-76.7089691'],
#    'lat': '37.2731156',
#    'lon': '-76.7090191',
#    'display_name': 'William & Mary Spirit Shop and Bookstore, 601, Prince George Street, Williamsburg, Williamsburg (city), Virginia, 23185, USA',
#    'class': 'shop',
#    'type': 'books',
#    'importance': 0.31010000000000004},
#   {'place_id': '98706622',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'node',
#    'osm_id': '9794684955',
#    'boundingbox': ['37.2728334', '37.2729334', '-76.7074184', '-76.7073184'],
#    'lat': '37.2728834',
#    'lon': '-76.7073684',
#    'display_name': 'William & Mary Institute for Integrative Conservation, 221, North Boundary Street, Williamsburg, Williamsburg (city), Virginia, 23185, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.31001,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '118635093',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '41263706',
#    'boundingbox': ['37.2678253', '37.2681029', '-76.7179793', '-76.7177905'],
#    'lat': '37.2679577',
#    'lon': '-76.7178875045662',
#    'display_name': 'William And Mary Campus Police, Ukrop Way, Williamsburg, Williamsburg (city), Virginia, 23187, USA',
#    'class': 'amenity',
#    'type': 'police',
#    'importance': 0.31001,
#    'icon': 'https://locationiq.org/static/images/mapicons/amenity_police2.p.20.png'},
#   {'place_id': '105480209',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '11182091',
#    'boundingbox': ['28.4088489', '28.4102012', '-81.4492999', '-81.449297'],
#    'lat': '28.409611',
#    'lon': '-81.449297',
#    'display_name': 'William & Mary Court, Windmill Point, Williamsburg CDP, Orange County, Florida, 32821, USA',
#    'class': 'highway',
#    'type': 'residential',
#    'importance': 0.41001},
#   {'place_id': '103861447',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '7774611',
#    'boundingbox': ['33.3975376', '33.4004153', '-86.7846671', '-86.7826788'],
#    'lat': '33.3988512',
#    'lon': '-86.783188',
#    'display_name': 'William and Mary Road, Williamsburg, Cedar Crest, Hoover, Jefferson County, Alabama, 35216, USA',
#    'class': 'highway',
#    'type': 'residential',
#    'importance': 0.41001},
#   {'place_id': '276450324',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '890912990',
#    'boundingbox': ['33.3973952', '33.3975376', '-86.7835944', '-86.7835902'],
#    'lat': '33.3975376',
#    'lon': '-86.7835944',
#    'display_name': 'William and Mary Road, Cedar Crest, Cedar Crest, Hoover, Jefferson County, Alabama, 35216, USA',
#    'class': 'highway',
#    'type': 'residential',
#    'importance': 0.30000999999999994}],
#  [{'place_id': '222558709',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '541752353',
#    'boundingbox': ['46.9987702', '47.014141', '-120.5472958', '-120.5195135'],
#    'lat': '47.00646895',
#    'lon': '-120.53673039883022',
#    'display_name': 'Central Washington University, 400, East University Way, Ellensburg, Kittitas County, Washington, 98926, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8139491882884298,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '154325349',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '197732218',
#    'boundingbox': ['47.4865519', '47.4964339', '-117.5935599', '-117.5762699'],
#    'lat': '47.4915232',
#    'lon': '-117.58586751653681',
#    'display_name': 'Eastern Washington University, 526, 5th Street, Cheney, Spokane County, Washington, 99004, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8265979186171462,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  {'error': 'Unable to geocode'},
#  [{'place_id': '118561736',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '41656208',
#    'boundingbox': ['47.7563356', '47.7627018', '-122.1937287', '-122.1882653'],
#    'lat': '47.75948765',
#    'lon': '-122.19100770512512',
#    'display_name': 'University of Washington-Bothell, South Campus Way, Bothell, King County, Washington, 98011, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.9327787078968703,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '333802702675',
#    'osm_type': 'way',
#    'osm_id': '431788141',
#    'licence': 'https://locationiq.com/attribution',
#    'lat': '47.245599',
#    'lon': '-122.438337',
#    'display_name': 'University of Washington Tacoma, 1900, Commerce Street, Tacoma, Pierce County, Washington, 98402, USA',
#    'boundingbox': ['47.2424697', '47.2477974', '-122.4430325', '-122.4365857'],
#    'importance': 0.25}],
#  [{'place_id': '128349498',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '95345602',
#    'boundingbox': ['48.7264107', '48.7409078', '-122.4917467', '-122.482475'],
#    'lat': '48.734140999999994',
#    'lon': '-122.48746401919874',
#    'display_name': 'Western Washington University, 516, High Street, Bellingham, Whatcom County, Washington, 98225, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8347015259107613,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '197749444',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '386835483',
#    'boundingbox': ['38.3744368', '38.3846219', '-81.7734551', '-81.762855'],
#    'lat': '38.3793907',
#    'lon': '-81.76806034458825',
#    'display_name': 'West Virginia State University, Marina Street, Institute, Jefferson, Kanawha County, West Virginia, 25112, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8821284718961503,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '143255474',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '154937796',
#    'boundingbox': ['39.631294', '39.6390645', '-79.9586563', '-79.9494124'],
#    'lat': '39.63471505',
#    'lon': '-79.95425356475369',
#    'display_name': 'West Virginia University, Life Science Stairs, Sunnyside, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862193',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392605',
#    'boundingbox': ['39.6377222', '39.6386189', '-79.9526504', '-79.951255'],
#    'lat': '39.63811235',
#    'lon': '-79.95191973107373',
#    'display_name': 'West Virginia University, Falling Run Road, Sunnyside, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862195',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392607',
#    'boundingbox': ['39.6347615', '39.6372818', '-79.9473639', '-79.9438361'],
#    'lat': '39.6359346',
#    'lon': '-79.94475585358785',
#    'display_name': 'West Virginia University, Stanton Avenue, Woodburn, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862197',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392609',
#    'boundingbox': ['39.6298056', '39.6301454', '-79.9573666', '-79.9569748'],
#    'lat': '39.6299769',
#    'lon': '-79.95718202157514',
#    'display_name': 'West Virginia University, Court Street, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862198',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392610',
#    'boundingbox': ['39.6282798', '39.6286239', '-79.9556364', '-79.9551841'],
#    'lat': '39.62847845',
#    'lon': '-79.95540413497889',
#    'display_name': 'West Virginia University, Spruce Street, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862199',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392611',
#    'boundingbox': ['39.6254161', '39.6258705', '-79.9634114', '-79.962806'],
#    'lat': '39.6256302',
#    'lon': '-79.96310731507394',
#    'display_name': 'West Virginia University, Donley Street, Hopecrest, Morgantown, Monongalia County, West Virginia, 26501, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862200',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392612',
#    'boundingbox': ['39.6243626', '39.6250058', '-79.9639899', '-79.9630716'],
#    'lat': '39.62469605',
#    'lon': '-79.96352960462474',
#    'display_name': 'West Virginia University, Caperton Trail, Hopecrest, Morgantown, Monongalia County, West Virginia, 26501, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862201',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392613',
#    'boundingbox': ['39.6419045', '39.6429489', '-79.965494', '-79.9634011'],
#    'lat': '39.642506049999994',
#    'lon': '-79.96439248081529',
#    'display_name': 'West Virginia University, Monongahela Boulevard, Seneca, Evansdale, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862202',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392614',
#    'boundingbox': ['39.642981', '39.6579393', '-79.979189', '-79.9528769'],
#    'lat': '39.6504472',
#    'lon': '-79.95565395071841',
#    'display_name': 'West Virginia University, Riverview Drive, The Flatts, Evansdale, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'},
#   {'place_id': '358862203',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '1156392615',
#    'boundingbox': ['39.6537701', '39.6551704', '-79.9650772', '-79.9637107'],
#    'lat': '39.65477025',
#    'lon': '-79.96439384681466',
#    'display_name': 'West Virginia University, Van Voorhis Road, The Flatts, Evansdale, Morgantown, Monongalia County, West Virginia, 26505, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.41009999999999996,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '304879182',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'relation',
#    'osm_id': '9965940',
#    'boundingbox': ['44.0178266', '44.0307817', '-88.5647531', '-88.545439'],
#    'lat': '44.02519995',
#    'lon': '-88.55108993473048',
#    'display_name': 'University of Wisconsin-Oshkosh, 800, Algoma Boulevard, Oshkosh, Winnebago County, Wisconsin, 54901, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.9174211450154455,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '152614942',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '190908355',
#    'boundingbox': ['42.6391452', '42.6540369', '-87.8763288', '-87.8411278'],
#    'lat': '42.6468292',
#    'lon': '-87.85040546563803',
#    'display_name': 'University of Wisconsin-Parkside, 900, Wood Road, Village of Somers, Kenosha County, Wisconsin, 53144, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.8895998267567611,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '217260546',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'way',
#    'osm_id': '502779686',
#    'boundingbox': ['42.8349884', '42.8537125', '-88.7520822', '-88.7347688'],
#    'lat': '42.84435955',
#    'lon': '-88.74366642884807',
#    'display_name': 'University of Wisconsin-Whitewater, 800, West Main Street, Historic Starin Park, Whitewater, Walworth County, Wisconsin, 53190, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.9000339655072036,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}],
#  [{'place_id': '351211186',
#    'licence': 'https://locationiq.com/attribution',
#    'osm_type': 'relation',
#    'osm_id': '15058634',
#    'boundingbox': ['41.3059038', '41.3188813', '-105.6132701', '-105.5575354'],
#    'lat': '41.3142264',
#    'lon': '-105.56432320214466',
#    'display_name': 'University of Wyoming, 1000, East University Avenue, Downtown Laramie, Laramie, Albany County, Wyoming, 82072, USA',
#    'class': 'amenity',
#    'type': 'university',
#    'importance': 0.9108714521059034,
#    'icon': 'https://locationiq.org/static/images/mapicons/education_university.p.20.png'}]]

# %%
for i, r in enumerate(responses):
    if 'error' in r:
        print(cc_data['name'][wrong_state.index[i]])
    else:
        cc_data['address'][wrong_state.index[i]] = r[0]['display_name']
        cc_data['lat'][wrong_state.index[i]] = float(r[0]['lat'])
        cc_data['lon'][wrong_state.index[i]] = float(r[0]['lon'])
# Out:
# Colorado State University-Global Campus
# University of Colorado Denver/Anschutz Medical Campus
# The University of West Florida
# University of Southern Indiana
# Northwestern State University of Louisiana
# University of Maryland Global Campus
# University of Minnesota-Twin Cities
# Mississippi Valley State University
# Ohio University-Main Campus
# Wright State University-Main Campus
# Virginia State University
# The Evergreen State College
# C:\Users\Sam Ehrenstein\AppData\Local\Temp\ipykernel_28796\685767713.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_data['address'][wrong_state.index[i]] = r[0]['display_name']
# C:\Users\Sam Ehrenstein\AppData\Local\Temp\ipykernel_28796\685767713.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_data['lat'][wrong_state.index[i]] = float(r[0]['lat'])
# C:\Users\Sam Ehrenstein\AppData\Local\Temp\ipykernel_28796\685767713.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_data['lon'][wrong_state.index[i]] = float(r[0]['lon'])

# %%
if 'geometry' in cc_data:
    cc_data.pop('geometry')
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, feature='states')

map = alt.Chart(states).mark_geoshape(
        fill='lightgray',
        stroke='white'
    ).project('albersUsa').properties(
        width=800,
        height=600
    )
points = alt.Chart(cc_data).mark_circle().encode(
    longitude='lon:Q',
    latitude='lat:Q',
    color=alt.Color('Basic:N'),
    tooltip=['name:N','lon:Q']
).project("albersUsa")
map + points
# Out:
# alt.LayerChart(...)

# %%
cc_data.to_csv('data_processed.csv')

# %%
geos
# Out:
#                         geometry  \
# 18                   POINT EMPTY
# 178     POINT (0.00970 51.54433)
# 219    POINT (77.23261 28.66446)
# 220   POINT (-90.34263 33.51126)
# 236    POINT (72.59375 23.10587)
# 248  POINT (151.23466 -33.90624)
# 261   POINT (-74.17903 40.74213)
# 270                  POINT EMPTY
# 276   POINT (-73.89016 40.87334)
# 278   POINT (-73.82520 40.73700)
# 294    POINT (-0.00512 51.48077)
# 296  POINT (-122.02395 37.40813)
# 362   POINT (-74.24522 40.74414)
# 373  POINT (-111.65500 35.18344)
# 374   POINT (-91.77386 37.95289)
# 381   POINT (-85.73034 36.03634)
# 427   POINT (-73.19415 44.47374)
# 439   POINT (-77.95838 37.09116)
#
#                                                address
# 18                                                None
# 178  University of East London (Stratford Campus), ...
# 219  Indira Gandhi Delhi Technical University for W...
# 220  Mississippi Valley State University, County Ro...
# 236  Gujarat Technological University, 382424, Ahme...
# 248  University of New South Wales Randwick Campus,...
# 261  New Jersey Institute of Technology, University...
# 270                                               None
# 276  Bedford Park Boulevard–Lehman College, Bedford...
# 278  Main Street & CUNY Queens College, Main Street...
# 294  National Maritime Museum, Old Royal Naval Coll...
# 296  Cogswell Polytechnical College, Bordeaux Drive...
# 362  Caroline D. Schwartz College of Nursing, South...
# 373  Northern Arizona University, West Forest Meado...
# 374  Missouri University of Science and Technology,...
# 381  Tennessee Technological University Appalachian...
# 427  University of Vermont, Davis Road, 05401, Davi...
# 439  Virginia Polytechnical Institute Land, Virgini...
